# %% [markdown]
# # NY flights data analysis

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ## Data source
# https://github.com/hadley/nycflights13

# %% [markdown]
# ## Load data

# %%
airlines = pd.read_csv('Dane\\Dane\\airlines.csv')
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
weather = pd.read_csv(r'Dane\Dane\weather.csv', sep=';')
weather.head()
# Out:
#   origin_code  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0         EWR  2013      1    1     1  39.02  26.06  59.37     270.0
# 1         EWR  2013      1    1     2  39.02  26.96  61.63     250.0
# 2         EWR  2013      1    1     3  39.02  28.04  64.43     240.0
# 3         EWR  2013      1    1     4  39.92  28.04  62.21     250.0
# 4         EWR  2013      1    1     5  39.02  28.04  64.43     260.0
#
#    wind_speed  wind_gust  precip  pressure  visib             time_hour
# 0    10.35702        0.0     0.0    1012.0   10.0  2013-01-01T06:00:00Z
# 1     8.05546        0.0     0.0    1012.3   10.0  2013-01-01T07:00:00Z
# 2    11.50780        0.0     0.0    1012.5   10.0  2013-01-01T08:00:00Z
# 3    12.65858        0.0     0.0    1012.2   10.0  2013-01-01T09:00:00Z
# 4    12.65858        0.0     0.0    1011.9   10.0  2013-01-01T10:00:00Z

# %%
flights = pd.read_excel('Dane\\Dane\\flights.xlsx')
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute            time_hour
# 0      1400     5      15  2013-01-01 05:00:00
# 1      1416     5      29  2013-01-01 05:00:00
# 2      1089     5      40  2013-01-01 05:00:00
# 3      1576     5      45  2013-01-01 05:00:00
# 4       762     6       0  2013-01-01 06:00:00

# %%
planes = pd.read_csv('Dane\\Dane\\planes.txt', sep='\t')
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
with open('Dane\\Dane\\airports.json') as f:
    airports_json = json.load(f)

airports = pd.DataFrame(airports_json)

# %%
airports = pd.DataFrame(airports_json)
airports.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %% [markdown]
# ## Top 10 airplanes with longest time in the air analysis

# %%
# Fill in missing data
# Airtime - average air time for all flights rounded to the nearest whole number from the entire month
flights['air_time'] = flights['air_time'].fillna(np.round(flights['air_time'].mean()))
# Plane table year - median of the year of production
planes['year'] = planes['year'].fillna(planes['year'].median())

# %% [markdown]
# ### Manufacturer and model

# %%
# Include only flights with tailnum
top_10_air_time = flights[(flights['day'] <= 15) & (~flights['tailnum'].isna())].reset_index(drop=True)\
                            .loc[:, ['tailnum', 'air_time']]\
                            .merge(planes.loc[:, ['tailnum', 'manufacturer', 'model']], on='tailnum', how='left')\
                            .groupby(['manufacturer', 'model'])\
                            .agg({'air_time' : 'sum'}).reset_index()\
                            .sort_values('air_time', ascending=False).reset_index(drop=True)[:10]
top_10_air_time
# Out:
#        manufacturer            model  air_time
# 0            AIRBUS         A320-232  250071.0
# 1            BOEING          737-824  123399.0
# 2  AIRBUS INDUSTRIE         A320-232  114757.0
# 3           EMBRAER        EMB-145LR  101066.0
# 4            BOEING          757-222   79755.0
# 5           EMBRAER  ERJ 190-100 IGW   73541.0
# 6            BOEING          737-832   72894.0
# 7            BOEING          737-7H4   62482.0
# 8           EMBRAER        EMB-145XR   60970.0
# 9            AIRBUS         A320-214   60910.0

# %% [markdown]
# ### Type and year of production of the oldest version

# %%
# First type and first year of production of top 10 planes with longest time in the air 
planes.merge(top_10_air_time, on=['manufacturer', 'model'])\
        .groupby(['manufacturer', 'model'])\
        .agg({'year' : 'min', 
              'type' : 'first'})\
        .reset_index()
# Out:
#        manufacturer            model    year                     type
# 0            AIRBUS         A320-214  2001.0  Fixed wing multi engine
# 1            AIRBUS         A320-232  2001.0  Fixed wing multi engine
# 2  AIRBUS INDUSTRIE         A320-232  1993.0  Fixed wing multi engine
# 3            BOEING          737-7H4  1997.0  Fixed wing multi engine
# 4            BOEING          737-824  1998.0  Fixed wing multi engine
# 5            BOEING          737-832  1998.0  Fixed wing multi engine
# 6            BOEING          757-222  1989.0  Fixed wing multi engine
# 7           EMBRAER        EMB-145LR  1998.0  Fixed wing multi engine
# 8           EMBRAER        EMB-145XR  2002.0  Fixed wing multi engine
# 9           EMBRAER  ERJ 190-100 IGW  2001.0  Fixed wing multi engine

# %% [markdown]
# ## Carrier flights analysis

# %% [markdown]
# ### Highest number of not deleyed flights

# %%
# size() vs count() ; size() includes NaN
# All flights number
flights_count = flights.groupby('carrier')\
                       .size()\
                       .to_frame().reset_index()\
                       .rename({0 : 'flights_count'}, axis='columns')
flights_count
# Out:
#    carrier  flights_count
# 0       9E           1573
# 1       AA           2794
# 2       AS             62
# 3       B6           4427
# 4       DL           3690
# 5       EV           4171
# 6       F9             59
# 7       FL            328
# 8       HA             31
# 9       MQ           2271
# 10      OO              1
# 11      UA           4637
# 12      US           1602
# 13      VX            316
# 14      WN            996
# 15      YV             46

# %%
# Not delayed flights number
not_del_count = flights.fillna({'dep_delay' : 0})\
                       .query('dep_delay <= 0')\
                       .groupby('carrier')\
                       .agg({'year' : 'count'}).reset_index()\
                       .rename({'year' : 'not_del_count'}, axis='columns')
not_del_count
# Out:
#    carrier  not_del_count
# 0       9E            999
# 1       AA           1890
# 2       AS             39
# 3       B6           2693
# 4       DL           2892
# 5       EV           2119
# 6       F9             45
# 7       FL            252
# 8       HA             20
# 9       MQ           1708
# 10      UA           2567
# 11      US           1253
# 12      VX            227
# 13      WN            607
# 14      YV             31

# %%
# Fill na values
flights_with_not_del = flights_count.merge(not_del_count, on='carrier', how='left').fillna(0)

# %%
# Not delayed flights percentage
flights_with_not_del['not_del_pr'] = flights_with_not_del['not_del_count']/flights_with_not_del['flights_count']

# %%
# Sort by not delayed flights percentage
flights_with_not_del.sort_values('not_del_pr', ascending=False).reset_index(drop=True)
# Out:
#    carrier  flights_count  not_del_count  not_del_pr
# 0       DL           3690         2892.0    0.783740
# 1       US           1602         1253.0    0.782147
# 2       FL            328          252.0    0.768293
# 3       F9             59           45.0    0.762712
# 4       MQ           2271         1708.0    0.752092
# 5       VX            316          227.0    0.718354
# 6       AA           2794         1890.0    0.676450
# 7       YV             46           31.0    0.673913
# 8       HA             31           20.0    0.645161
# 9       9E           1573          999.0    0.635092
# 10      AS             62           39.0    0.629032
# 11      WN            996          607.0    0.609438
# 12      B6           4427         2693.0    0.608313
# 13      UA           4637         2567.0    0.553591
# 14      EV           4171         2119.0    0.508032
# 15      OO              1            0.0    0.000000

# %% [markdown]
# ### Highest number of delays

# %%
# Fill in delay missing data with 0
flights['dep_delay'] = flights['dep_delay'].fillna(0)

# %%
# Count flights by carrier and origin
f_count = flights.groupby(['carrier', 'origin'])\
                 .agg({'year' : 'count'}).reset_index()\
                 .rename({'year' : 'f_count'}, axis='columns')
f_count
# Out:
#    carrier origin  f_count
# 0       9E    EWR       82
# 1       9E    JFK     1419
# 2       9E    LGA       72
# 3       AA    EWR      298
# 4       AA    JFK     1236
# 5       AA    LGA     1260
# 6       AS    EWR       62
# 7       B6    EWR      573
# 8       B6    JFK     3327
# 9       B6    LGA      527
# 10      DL    EWR      279
# 11      DL    JFK     1522
# 12      DL    LGA     1889
# 13      EV    EWR     3838
# 14      EV    JFK      108
# 15      EV    LGA      225
# 16      F9    LGA       59
# 17      FL    LGA      328
# 18      HA    JFK       31
# 19      MQ    EWR      212
# 20      MQ    JFK      589
# 21      MQ    LGA     1470
# 22      OO    LGA        1
# 23      UA    EWR     3657
# 24      UA    JFK      380
# 25      UA    LGA      600
# 26      US    EWR      363
# 27      US    JFK      233
# 28      US    LGA     1006
# 29      VX    JFK      316
# 30      WN    EWR      529
# 31      WN    LGA      467
# 32      YV    LGA       46

# %%
# Statistics for delayed flights 
tmp = flights[flights['dep_delay'] > 0]\
            .groupby(['carrier', 'origin'])\
            .agg({'day' : 'count',
                  'dep_delay' : ['mean', 
                                 'max', 
                                 np.median]})
tmp
# Out:
# C:\Users\Marcin\AppData\Local\Temp\ipykernel_35860\1864549728.py:4: FutureWarning: The provided callable <function median at 0x000001F172FF5E40> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   .agg({'day' : 'count',
#                  day   dep_delay
#                count        mean     max median
# carrier origin
# 9E      EWR       18   77.000000   265.0   57.5
#         JFK      539   49.936920   360.0   24.0
#         LGA       17   88.647059   190.0  108.0
# AA      EWR       82   50.756098   285.0   27.0
#         JFK      445   29.773034   337.0   12.0
#         LGA      377   26.652520   210.0   12.0
# AS      EWR       23   31.869565   222.0   13.0
# B6      EWR      199   42.211055   502.0   18.0
#         JFK     1305   27.698084   315.0   15.0
#         LGA      230   38.765217   366.0   17.0
# DL      EWR       61   43.852459   262.0   20.0
#         JFK      337   30.991098   599.0   13.0
#         LGA      400   32.810000   478.0   16.0
# EV      EWR     1930   51.553886   379.0   34.0
#         JFK       31   54.967742   266.0   31.0
#         LGA       91   52.087912   275.0   30.0
# F9      LGA       14   55.571429   248.0   11.0
# FL      LGA       76   27.565789   210.0   12.0
# HA      JFK       11  159.272727  1301.0   20.0
# MQ      EWR       58   60.517241  1126.0   27.5
#         JFK      164   43.682927   853.0   21.0
#         LGA      341   38.093842   220.0   26.0
# OO      LGA        1   67.000000    67.0   67.0
# UA      EWR     1726   21.904403   334.0    9.0
#         JFK       94   21.808511   293.0    8.0
#         LGA      250   29.900000   385.0    9.5
# US      EWR       68   28.029412   214.0    9.5
#         JFK       79   21.886076   164.0    7.0
#         LGA      202   27.306931   336.0   17.0
# VX      JFK       89   14.741573   246.0    7.0
# WN      EWR      210   29.342857   256.0   13.0
#         LGA      179   26.217877   259.0   10.0
# YV      LGA       15   50.333333   238.0   37.0

# %%
# Drop multiindex for columns
tmp.columns = tmp.columns.droplevel()
tmp
# Out:
#                 count        mean     max  median
# carrier origin
# 9E      EWR        18   77.000000   265.0    57.5
#         JFK       539   49.936920   360.0    24.0
#         LGA        17   88.647059   190.0   108.0
# AA      EWR        82   50.756098   285.0    27.0
#         JFK       445   29.773034   337.0    12.0
#         LGA       377   26.652520   210.0    12.0
# AS      EWR        23   31.869565   222.0    13.0
# B6      EWR       199   42.211055   502.0    18.0
#         JFK      1305   27.698084   315.0    15.0
#         LGA       230   38.765217   366.0    17.0
# DL      EWR        61   43.852459   262.0    20.0
#         JFK       337   30.991098   599.0    13.0
#         LGA       400   32.810000   478.0    16.0
# EV      EWR      1930   51.553886   379.0    34.0
#         JFK        31   54.967742   266.0    31.0
#         LGA        91   52.087912   275.0    30.0
# F9      LGA        14   55.571429   248.0    11.0
# FL      LGA        76   27.565789   210.0    12.0
# HA      JFK        11  159.272727  1301.0    20.0
# MQ      EWR        58   60.517241  1126.0    27.5
#         JFK       164   43.682927   853.0    21.0
#         LGA       341   38.093842   220.0    26.0
# OO      LGA         1   67.000000    67.0    67.0
# UA      EWR      1726   21.904403   334.0     9.0
#         JFK        94   21.808511   293.0     8.0
#         LGA       250   29.900000   385.0     9.5
# US      EWR        68   28.029412   214.0     9.5
#         JFK        79   21.886076   164.0     7.0
#         LGA       202   27.306931   336.0    17.0
# VX      JFK        89   14.741573   246.0     7.0
# WN      EWR       210   29.342857   256.0    13.0
#         LGA       179   26.217877   259.0    10.0
# YV      LGA        15   50.333333   238.0    37.0

# %%
# Rename columns
f_count_del = tmp.reset_index()\
                .rename({'count' : 'd_count', 
                         'mean' : 'd_mean', 
                         'median' : 'd_median', 
                         'max' : 'd_max'}, axis='columns')
f_count_del
# Out:
#    carrier origin  d_count      d_mean   d_max  d_median
# 0       9E    EWR       18   77.000000   265.0      57.5
# 1       9E    JFK      539   49.936920   360.0      24.0
# 2       9E    LGA       17   88.647059   190.0     108.0
# 3       AA    EWR       82   50.756098   285.0      27.0
# 4       AA    JFK      445   29.773034   337.0      12.0
# 5       AA    LGA      377   26.652520   210.0      12.0
# 6       AS    EWR       23   31.869565   222.0      13.0
# 7       B6    EWR      199   42.211055   502.0      18.0
# 8       B6    JFK     1305   27.698084   315.0      15.0
# 9       B6    LGA      230   38.765217   366.0      17.0
# 10      DL    EWR       61   43.852459   262.0      20.0
# 11      DL    JFK      337   30.991098   599.0      13.0
# 12      DL    LGA      400   32.810000   478.0      16.0
# 13      EV    EWR     1930   51.553886   379.0      34.0
# 14      EV    JFK       31   54.967742   266.0      31.0
# 15      EV    LGA       91   52.087912   275.0      30.0
# 16      F9    LGA       14   55.571429   248.0      11.0
# 17      FL    LGA       76   27.565789   210.0      12.0
# 18      HA    JFK       11  159.272727  1301.0      20.0
# 19      MQ    EWR       58   60.517241  1126.0      27.5
# 20      MQ    JFK      164   43.682927   853.0      21.0
# 21      MQ    LGA      341   38.093842   220.0      26.0
# 22      OO    LGA        1   67.000000    67.0      67.0
# 23      UA    EWR     1726   21.904403   334.0       9.0
# 24      UA    JFK       94   21.808511   293.0       8.0
# 25      UA    LGA      250   29.900000   385.0       9.5
# 26      US    EWR       68   28.029412   214.0       9.5
# 27      US    JFK       79   21.886076   164.0       7.0
# 28      US    LGA      202   27.306931   336.0      17.0
# 29      VX    JFK       89   14.741573   246.0       7.0
# 30      WN    EWR      210   29.342857   256.0      13.0
# 31      WN    LGA      179   26.217877   259.0      10.0
# 32      YV    LGA       15   50.333333   238.0      37.0

# %%
# Merge f_count with f_count_del
flights_with_del = f_count.merge(f_count_del, on=['carrier', 'origin'], how='left').fillna(0)

# %%
# Calculate percentage of delayed flights
flights_with_del['pr'] = flights_with_del['d_count']/flights_with_del['f_count']

# %%
# Mark carrier and origin with more than 30% of delayed flights
flights_with_del['del_flag'] = flights_with_del['pr'].apply(lambda x: int(x>0.3))
flights_with_del
# Out:
#    carrier origin  f_count  d_count      d_mean   d_max  d_median        pr  \
# 0       9E    EWR       82       18   77.000000   265.0      57.5  0.219512
# 1       9E    JFK     1419      539   49.936920   360.0      24.0  0.379845
# 2       9E    LGA       72       17   88.647059   190.0     108.0  0.236111
# 3       AA    EWR      298       82   50.756098   285.0      27.0  0.275168
# 4       AA    JFK     1236      445   29.773034   337.0      12.0  0.360032
# 5       AA    LGA     1260      377   26.652520   210.0      12.0  0.299206
# 6       AS    EWR       62       23   31.869565   222.0      13.0  0.370968
# 7       B6    EWR      573      199   42.211055   502.0      18.0  0.347295
# 8       B6    JFK     3327     1305   27.698084   315.0      15.0  0.392245
# 9       B6    LGA      527      230   38.765217   366.0      17.0  0.436433
# 10      DL    EWR      279       61   43.852459   262.0      20.0  0.218638
# 11      DL    JFK     1522      337   30.991098   599.0      13.0  0.221419
# 12      DL    LGA     1889      400   32.810000   478.0      16.0  0.211752
# 13      EV    EWR     3838     1930   51.553886   379.0      34.0  0.502866
# 14      EV    JFK      108       31   54.967742   266.0      31.0  0.287037
# 15      EV    LGA      225       91   52.087912   275.0      30.0  0.404444
# 16      F9    LGA       59       14   55.571429   248.0      11.0  0.237288
# 17      FL    LGA      328       76   27.565789   210.0      12.0  0.231707
# 18      HA    JFK       31       11  159.272727  1301.0      20.0  0.354839
# 19      MQ    EWR      212       58   60.517241  1126.0      27.5  0.273585
# 20      MQ    JFK      589      164   43.682927   853.0      21.0  0.278438
# 21      MQ    LGA     1470      341   38.093842   220.0      26.0  0.231973
# 22      OO    LGA        1        1   67.000000    67.0      67.0  1.000000
# 23      UA    EWR     3657     1726   21.904403   334.0       9.0  0.471972
# 24      UA    JFK      380       94   21.808511   293.0       8.0  0.247368
# 25      UA    LGA      600      250   29.900000   385.0       9.5  0.416667
# 26      US    EWR      363       68   28.029412   214.0       9.5  0.187328
# 27      US    JFK      233       79   21.886076   164.0       7.0  0.339056
# 28      US    LGA     1006      202   27.306931   336.0      17.0  0.200795
# 29      VX    JFK      316       89   14.741573   246.0       7.0  0.281646
# 30      WN    EWR      529      210   29.342857   256.0      13.0  0.396975
# 31      WN    LGA      467      179   26.217877   259.0      10.0  0.383298
# 32      YV    LGA       46       15   50.333333   238.0      37.0  0.326087
#
#     del_flag
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# 5          0
# 6          1
# 7          1
# 8          1
# 9          1
# 10         0
# 11         0
# 12         0
# 13         1
# 14         0
# 15         1
# 16         0
# 17         0
# 18         1
# 19         0
# 20         0
# 21         0
# 22         1
# 23         1
# 24         0
# 25         1
# 26         0
# 27         1
# 28         0
# 29         0
# 30         1
# 31         1
# 32         1

# %%
# Set index to carrier
airlines.index = airlines['carrier']

# %%
# Create dictionary with carrier short and full name 
carriers_dict = airlines['name'].to_dict()
carriers_dict
# Out:
# {'9E': 'Endeavor Air Inc.',
#  'AA': 'American Airlines Inc.',
#  'AS': 'Alaska Airlines Inc.',
#  'B6': 'JetBlue Airways',
#  'DL': 'Delta Air Lines Inc.',
#  'EV': 'ExpressJet Airlines Inc.',
#  'F9': 'Frontier Airlines Inc.',
#  'FL': 'AirTran Airways Corporation',
#  'HA': 'Hawaiian Airlines Inc.',
#  'MQ': 'Envoy Air',
#  'OO': 'SkyWest Airlines Inc.',
#  'UA': 'United Air Lines Inc.',
#  'US': 'US Airways Inc.',
#  'VX': 'Virgin America',
#  'WN': 'Southwest Airlines Co.',
#  'YV': 'Mesa Airlines Inc.'}

# %%
# Map short name of carriers with its full name 
flights_with_del['carrier_full_name'] = flights_with_del['carrier'].map(carriers_dict)
flights_with_del
# Out:
#    carrier origin  f_count  d_count      d_mean   d_max  d_median        pr  \
# 0       9E    EWR       82       18   77.000000   265.0      57.5  0.219512
# 1       9E    JFK     1419      539   49.936920   360.0      24.0  0.379845
# 2       9E    LGA       72       17   88.647059   190.0     108.0  0.236111
# 3       AA    EWR      298       82   50.756098   285.0      27.0  0.275168
# 4       AA    JFK     1236      445   29.773034   337.0      12.0  0.360032
# 5       AA    LGA     1260      377   26.652520   210.0      12.0  0.299206
# 6       AS    EWR       62       23   31.869565   222.0      13.0  0.370968
# 7       B6    EWR      573      199   42.211055   502.0      18.0  0.347295
# 8       B6    JFK     3327     1305   27.698084   315.0      15.0  0.392245
# 9       B6    LGA      527      230   38.765217   366.0      17.0  0.436433
# 10      DL    EWR      279       61   43.852459   262.0      20.0  0.218638
# 11      DL    JFK     1522      337   30.991098   599.0      13.0  0.221419
# 12      DL    LGA     1889      400   32.810000   478.0      16.0  0.211752
# 13      EV    EWR     3838     1930   51.553886   379.0      34.0  0.502866
# 14      EV    JFK      108       31   54.967742   266.0      31.0  0.287037
# 15      EV    LGA      225       91   52.087912   275.0      30.0  0.404444
# 16      F9    LGA       59       14   55.571429   248.0      11.0  0.237288
# 17      FL    LGA      328       76   27.565789   210.0      12.0  0.231707
# 18      HA    JFK       31       11  159.272727  1301.0      20.0  0.354839
# 19      MQ    EWR      212       58   60.517241  1126.0      27.5  0.273585
# 20      MQ    JFK      589      164   43.682927   853.0      21.0  0.278438
# 21      MQ    LGA     1470      341   38.093842   220.0      26.0  0.231973
# 22      OO    LGA        1        1   67.000000    67.0      67.0  1.000000
# 23      UA    EWR     3657     1726   21.904403   334.0       9.0  0.471972
# 24      UA    JFK      380       94   21.808511   293.0       8.0  0.247368
# 25      UA    LGA      600      250   29.900000   385.0       9.5  0.416667
# 26      US    EWR      363       68   28.029412   214.0       9.5  0.187328
# 27      US    JFK      233       79   21.886076   164.0       7.0  0.339056
# 28      US    LGA     1006      202   27.306931   336.0      17.0  0.200795
# 29      VX    JFK      316       89   14.741573   246.0       7.0  0.281646
# 30      WN    EWR      529      210   29.342857   256.0      13.0  0.396975
# 31      WN    LGA      467      179   26.217877   259.0      10.0  0.383298
# 32      YV    LGA       46       15   50.333333   238.0      37.0  0.326087
#
#     del_flag            carrier_full_name
# 0          0            Endeavor Air Inc.
# 1          1            Endeavor Air Inc.
# 2          0            Endeavor Air Inc.
# 3          0       American Airlines Inc.
# 4          1       American Airlines Inc.
# 5          0       American Airlines Inc.
# 6          1         Alaska Airlines Inc.
# 7          1              JetBlue Airways
# 8          1              JetBlue Airways
# 9          1              JetBlue Airways
# 10         0         Delta Air Lines Inc.
# 11         0         Delta Air Lines Inc.
# 12         0         Delta Air Lines Inc.
# 13         1     ExpressJet Airlines Inc.
# 14         0     ExpressJet Airlines Inc.
# 15         1     ExpressJet Airlines Inc.
# 16         0       Frontier Airlines Inc.
# 17         0  AirTran Airways Corporation
# 18         1       Hawaiian Airlines Inc.
# 19         0                    Envoy Air
# 20         0                    Envoy Air
# 21         0                    Envoy Air
# 22         1        SkyWest Airlines Inc.
# 23         1        United Air Lines Inc.
# 24         0        United Air Lines Inc.
# 25         1        United Air Lines Inc.
# 26         0              US Airways Inc.
# 27         1              US Airways Inc.
# 28         0              US Airways Inc.
# 29         0               Virgin America
# 30         1       Southwest Airlines Co.
# 31         1       Southwest Airlines Co.
# 32         1           Mesa Airlines Inc.

# %%
# Sort final table
flights_with_del.sort_values('d_count', ascending=False)
# Out:
#    carrier origin  f_count  d_count      d_mean   d_max  d_median        pr  \
# 13      EV    EWR     3838     1930   51.553886   379.0      34.0  0.502866
# 23      UA    EWR     3657     1726   21.904403   334.0       9.0  0.471972
# 8       B6    JFK     3327     1305   27.698084   315.0      15.0  0.392245
# 1       9E    JFK     1419      539   49.936920   360.0      24.0  0.379845
# 4       AA    JFK     1236      445   29.773034   337.0      12.0  0.360032
# 12      DL    LGA     1889      400   32.810000   478.0      16.0  0.211752
# 5       AA    LGA     1260      377   26.652520   210.0      12.0  0.299206
# 21      MQ    LGA     1470      341   38.093842   220.0      26.0  0.231973
# 11      DL    JFK     1522      337   30.991098   599.0      13.0  0.221419
# 25      UA    LGA      600      250   29.900000   385.0       9.5  0.416667
# 9       B6    LGA      527      230   38.765217   366.0      17.0  0.436433
# 30      WN    EWR      529      210   29.342857   256.0      13.0  0.396975
# 28      US    LGA     1006      202   27.306931   336.0      17.0  0.200795
# 7       B6    EWR      573      199   42.211055   502.0      18.0  0.347295
# 31      WN    LGA      467      179   26.217877   259.0      10.0  0.383298
# 20      MQ    JFK      589      164   43.682927   853.0      21.0  0.278438
# 24      UA    JFK      380       94   21.808511   293.0       8.0  0.247368
# 15      EV    LGA      225       91   52.087912   275.0      30.0  0.404444
# 29      VX    JFK      316       89   14.741573   246.0       7.0  0.281646
# 3       AA    EWR      298       82   50.756098   285.0      27.0  0.275168
# 27      US    JFK      233       79   21.886076   164.0       7.0  0.339056
# 17      FL    LGA      328       76   27.565789   210.0      12.0  0.231707
# 26      US    EWR      363       68   28.029412   214.0       9.5  0.187328
# 10      DL    EWR      279       61   43.852459   262.0      20.0  0.218638
# 19      MQ    EWR      212       58   60.517241  1126.0      27.5  0.273585
# 14      EV    JFK      108       31   54.967742   266.0      31.0  0.287037
# 6       AS    EWR       62       23   31.869565   222.0      13.0  0.370968
# 0       9E    EWR       82       18   77.000000   265.0      57.5  0.219512
# 2       9E    LGA       72       17   88.647059   190.0     108.0  0.236111
# 32      YV    LGA       46       15   50.333333   238.0      37.0  0.326087
# 16      F9    LGA       59       14   55.571429   248.0      11.0  0.237288
# 18      HA    JFK       31       11  159.272727  1301.0      20.0  0.354839
# 22      OO    LGA        1        1   67.000000    67.0      67.0  1.000000
#
#     del_flag            carrier_full_name
# 13         1     ExpressJet Airlines Inc.
# 23         1        United Air Lines Inc.
# 8          1              JetBlue Airways
# 1          1            Endeavor Air Inc.
# 4          1       American Airlines Inc.
# 12         0         Delta Air Lines Inc.
# 5          0       American Airlines Inc.
# 21         0                    Envoy Air
# 11         0         Delta Air Lines Inc.
# 25         1        United Air Lines Inc.
# 9          1              JetBlue Airways
# 30         1       Southwest Airlines Co.
# 28         0              US Airways Inc.
# 7          1              JetBlue Airways
# 31         1       Southwest Airlines Co.
# 20         0                    Envoy Air
# 24         0        United Air Lines Inc.
# 15         1     ExpressJet Airlines Inc.
# 29         0               Virgin America
# 3          0       American Airlines Inc.
# 27         1              US Airways Inc.
# 17         0  AirTran Airways Corporation
# 26         0              US Airways Inc.
# 10         0         Delta Air Lines Inc.
# 19         0                    Envoy Air
# 14         0     ExpressJet Airlines Inc.
# 6          1         Alaska Airlines Inc.
# 0          0            Endeavor Air Inc.
# 2          0            Endeavor Air Inc.
# 32         1           Mesa Airlines Inc.
# 16         0       Frontier Airlines Inc.
# 18         1       Hawaiian Airlines Inc.
# 22         1        SkyWest Airlines Inc.

# %% [markdown]
# ### Highest number of flights outside of NY

# %%
# Get area from tzone
airports['area'] = airports['tzone'].apply(lambda x: x.split('/')[1].replace('_', ' ') if x else x)

# %%
# Different_tzone_flights_count - count of flights outside the start area by carrier and origin
# No timezone information - assume flight outside the start area
# Show only combinations with the flights count > 100
flights_outside_NY = flights.loc[:, ['carrier', 'origin', 'dest']]\
                            .merge(airports.loc[:, ['faa', 'area']], left_on='origin', right_on='faa', how='left')\
                            .rename({'area' : 'dep_area'}, axis='columns')\
                            .merge(airports.loc[:, ['faa', 'area']], left_on='dest', right_on='faa', how='left')\
                            .rename({'area' : 'arr_area'}, axis='columns')\
                            .drop(['faa_x', 'faa_y'], axis='columns')\
                            .query('dep_area != arr_area').reset_index(drop=True)\
                            .groupby(['carrier', 'origin'])\
                            .agg({'dest' : 'count'}).reset_index()\
                            .query('dest>=100').reset_index(drop=True)\
                            .sort_values('dest', ascending=False).reset_index(drop=True)\
                            .rename({'dest' : 'different_tzone_flights_count'}, axis='columns')

flights_outside_NY
# Out:
#    carrier origin  different_tzone_flights_count
# 0       UA    EWR                           2074
# 1       B6    JFK                           1201
# 2       AA    LGA                            929
# 3       DL    JFK                            923
# 4       EV    EWR                            902
# 5       AA    JFK                            767
# 6       UA    LGA                            573
# 7       WN    LGA                            452
# 8       WN    EWR                            442
# 9       DL    LGA                            401
# 10      UA    JFK                            380
# 11      MQ    LGA                            355
# 12      VX    JFK                            316
# 13      9E    JFK                            302
# 14      MQ    EWR                            212
# 15      AA    EWR                            205

# %% [markdown]
# ### Most popular destination and maximum number of passengers it could carry on

# %%
# Most popular destination and maximum number of passengers it could carry on (the same timezone enabled)
most_pop_dest_max_passengers = flights_outside_NY.merge(
                                    flights.loc[:, ['carrier', 'origin', 'dest', 'tailnum']]\
                                        .merge(airports.loc[:, ['faa', 'area']], left_on='dest', right_on='faa', how='left')\
                                        .rename({'area' : 'arr_area'}, axis='columns')\
                                        .merge(planes.loc[:, ['tailnum', 'seats']], on='tailnum', how='left')\
                                        .groupby(['carrier', 'origin', 'arr_area'])\
                                        .agg({'faa' : 'count', 
                                              'seats' : 'sum'}).reset_index()\
                                        .sort_values(['carrier', 'origin', 'faa']).reset_index(drop=True)\
                                        .groupby(['carrier', 'origin'])\
                                        .agg({'arr_area' : 'last', 
                                              'faa' : 'last', 
                                              'seats' : 'last'}).reset_index()\
                                        .rename({'faa' : 'most_pop_arr_area_flights_count', 
                                                 'seats' : 'most_pop_arr_area_seats_sum', 
                                                 'arr_area' : 'most_pop_arr_area'}, axis='columns'), 
                                        on=['carrier', 'origin']
                            )

most_pop_dest_max_passengers
# Out:
#    carrier origin  different_tzone_flights_count most_pop_arr_area  \
# 0       UA    EWR                           2074          New York
# 1       B6    JFK                           1201          New York
# 2       AA    LGA                            929           Chicago
# 3       DL    JFK                            923          New York
# 4       EV    EWR                            902          New York
# 5       AA    JFK                            767       Los Angeles
# 6       UA    LGA                            573           Chicago
# 7       WN    LGA                            452           Chicago
# 8       WN    EWR                            442           Chicago
# 9       DL    LGA                            401          New York
# 10      UA    JFK                            380       Los Angeles
# 11      MQ    LGA                            355          New York
# 12      VX    JFK                            316       Los Angeles
# 13      9E    JFK                            302          New York
# 14      MQ    EWR                            212           Chicago
# 15      AA    EWR                            205           Chicago
#
#     most_pop_arr_area_flights_count  most_pop_arr_area_seats_sum
# 0                              1583                     265675.0
# 1                              2126                     247505.0
# 2                               929                      37891.0
# 3                               599                     103225.0
# 4                              2936                     165930.0
# 5                               488                      89984.0
# 6                               433                      74426.0
# 7                               391                      54944.0
# 8                               319                      44961.0
# 9                              1488                     243467.0
# 10                              380                      57268.0
# 11                             1115                       1360.0
# 12                              316                      57430.0
# 13                             1117                      79770.0
# 14                              212                         42.0
# 15                              174                      10722.0

# %%
# Map full names of origin airports
most_pop_dest_max_passengers['origin_full'] = most_pop_dest_max_passengers['origin']\
                                                .map({'EWR' : 'Newark Liberty International Airport', 
                                                      'JFK' : 'John F. Kennedy International Airport', 
                                                      'LGA' : 'LaGuardia Airport'})
most_pop_dest_max_passengers
# Out:
#    carrier origin  different_tzone_flights_count most_pop_arr_area  \
# 0       UA    EWR                           2074          New York
# 1       B6    JFK                           1201          New York
# 2       AA    LGA                            929           Chicago
# 3       DL    JFK                            923          New York
# 4       EV    EWR                            902          New York
# 5       AA    JFK                            767       Los Angeles
# 6       UA    LGA                            573           Chicago
# 7       WN    LGA                            452           Chicago
# 8       WN    EWR                            442           Chicago
# 9       DL    LGA                            401          New York
# 10      UA    JFK                            380       Los Angeles
# 11      MQ    LGA                            355          New York
# 12      VX    JFK                            316       Los Angeles
# 13      9E    JFK                            302          New York
# 14      MQ    EWR                            212           Chicago
# 15      AA    EWR                            205           Chicago
#
#     most_pop_arr_area_flights_count  most_pop_arr_area_seats_sum  \
# 0                              1583                     265675.0
# 1                              2126                     247505.0
# 2                               929                      37891.0
# 3                               599                     103225.0
# 4                              2936                     165930.0
# 5                               488                      89984.0
# 6                               433                      74426.0
# 7                               391                      54944.0
# 8                               319                      44961.0
# 9                              1488                     243467.0
# 10                              380                      57268.0
# 11                             1115                       1360.0
# 12                              316                      57430.0
# 13                             1117                      79770.0
# 14                              212                         42.0
# 15                              174                      10722.0
#
#                               origin_full
# 0    Newark Liberty International Airport
# 1   John F. Kennedy International Airport
# 2                       LaGuardia Airport
# 3   John F. Kennedy International Airport
# 4    Newark Liberty International Airport
# 5   John F. Kennedy International Airport
# 6                       LaGuardia Airport
# 7                       LaGuardia Airport
# 8    Newark Liberty International Airport
# 9                       LaGuardia Airport
# 10  John F. Kennedy International Airport
# 11                      LaGuardia Airport
# 12  John F. Kennedy International Airport
# 13  John F. Kennedy International Airport
# 14   Newark Liberty International Airport
# 15   Newark Liberty International Airport

# %%
# Sort final table
most_pop_dest_max_passengers.sort_values('most_pop_arr_area_flights_count', ascending=False)
# Out:
#    carrier origin  different_tzone_flights_count most_pop_arr_area  \
# 4       EV    EWR                            902          New York
# 1       B6    JFK                           1201          New York
# 0       UA    EWR                           2074          New York
# 9       DL    LGA                            401          New York
# 13      9E    JFK                            302          New York
# 11      MQ    LGA                            355          New York
# 2       AA    LGA                            929           Chicago
# 3       DL    JFK                            923          New York
# 5       AA    JFK                            767       Los Angeles
# 6       UA    LGA                            573           Chicago
# 7       WN    LGA                            452           Chicago
# 10      UA    JFK                            380       Los Angeles
# 8       WN    EWR                            442           Chicago
# 12      VX    JFK                            316       Los Angeles
# 14      MQ    EWR                            212           Chicago
# 15      AA    EWR                            205           Chicago
#
#     most_pop_arr_area_flights_count  most_pop_arr_area_seats_sum  \
# 4                              2936                     165930.0
# 1                              2126                     247505.0
# 0                              1583                     265675.0
# 9                              1488                     243467.0
# 13                             1117                      79770.0
# 11                             1115                       1360.0
# 2                               929                      37891.0
# 3                               599                     103225.0
# 5                               488                      89984.0
# 6                               433                      74426.0
# 7                               391                      54944.0
# 10                              380                      57268.0
# 8                               319                      44961.0
# 12                              316                      57430.0
# 14                              212                         42.0
# 15                              174                      10722.0
#
#                               origin_full
# 4    Newark Liberty International Airport
# 1   John F. Kennedy International Airport
# 0    Newark Liberty International Airport
# 9                       LaGuardia Airport
# 13  John F. Kennedy International Airport
# 11                      LaGuardia Airport
# 2                       LaGuardia Airport
# 3   John F. Kennedy International Airport
# 5   John F. Kennedy International Airport
# 6                       LaGuardia Airport
# 7                       LaGuardia Airport
# 10  John F. Kennedy International Airport
# 8    Newark Liberty International Airport
# 12  John F. Kennedy International Airport
# 14   Newark Liberty International Airport
# 15   Newark Liberty International Airport
